# %%
import pandas as pd
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
filename = 'consulta_cand_2020_SP.csv'
df = pd.read_csv(filename, delimiter=';', encoding='ISO-8859-1', error_bad_lines=False)

# %%
df.shape
# Out:
# (93695, 63)

# %%
df.describe()
# Out:
#        ANO_ELEICAO  CD_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO         SG_UE  \
# count      93695.0          93695.0   93695.0     93695.0  93695.000000
# mean        2020.0              2.0       1.0       426.0  66533.119099
# std            0.0              0.0       0.0         0.0   3475.926202
# min         2020.0              2.0       1.0       426.0  61000.000000
# 25%         2020.0              2.0       1.0       426.0  63312.000000
# 50%         2020.0              2.0       1.0       426.0  66370.000000
# 75%         2020.0              2.0       1.0       426.0  69710.000000
# max         2020.0              2.0       1.0       426.0  72737.000000
#
#            CD_CARGO  SQ_CANDIDATO  NR_CANDIDATO  NR_CPF_CANDIDATO  \
# count  93695.000000  9.369500e+04  93695.000000      9.369500e+04
# mean      12.913624  2.500010e+11  29279.626725      2.587108e+10
# std        0.368978  1.809075e+05  20380.215808      2.040171e+10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93695 entries, 0 to 93694
# Data columns (total 63 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     93695 non-null  object
#  1   HH_GERACAO                     93695 non-null  object
#  2   ANO_ELEICAO                    93695 non-null  int64
#  3   CD_TIPO_ELEICAO                93695 non-null  int64
#  4   NM_TIPO_ELEICAO                93695 non-null  object
#  5   NR_TURNO                       93695 non-null  int64
#  6   CD_ELEICAO                     93695 non-null  int64
#  7   DS_ELEICAO                     93695 non-null  object
#  8   DT_ELEICAO                     93695 non-null  object
#  9   TP_ABRANGENCIA                 93695 non-null  object
#  10  SG_UF                          93695 non-null  object
#  11  SG_UE                          93695 non-null  int64
# ...

# %%
df.sample(25)
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 78902  05/11/2020   17:07:09         2020                2  ELEIÇÃO ORDINÁRIA
# 50162  05/11/2020   17:07:09         2020                2  ELEIÇÃO ORDINÁRIA
# 1279   05/11/2020   17:07:09         2020                2  ELEIÇÃO ORDINÁRIA
# 27067  05/11/2020   17:07:09         2020                2  ELEIÇÃO ORDINÁRIA
# 90877  05/11/2020   17:07:09         2020                2  ELEIÇÃO ORDINÁRIA
# 85094  05/11/2020   17:07:09         2020                2  ELEIÇÃO ORDINÁRIA
# 22847  05/11/2020   17:07:09         2020                2  ELEIÇÃO ORDINÁRIA
# 19420  05/11/2020   17:07:09         2020                2  ELEIÇÃO ORDINÁRIA
# 92141  05/11/2020   17:07:09         2020                2  ELEIÇÃO ORDINÁRIA
# 53092  05/11/2020   17:07:09         2020                2  ELEIÇÃO ORDINÁRIA
# 68448  05/11/2020   17:07:09         2020                2  ELEIÇÃO ORDINÁRIA
# ...

# %%
df.query('NM_UE == "SÃO JOSÉ DOS CAMPOS"')['DS_CARGO'].value_counts().head().plot(kind='barh')

# %%
df.query('NM_UE == "SÃO JOSÉ DOS CAMPOS"')['DS_COR_RACA'].value_counts().head()
# Out:
# BRANCA      451
# PARDA        97
# PRETA        67
# AMARELA       5
# INDÍGENA      1
# Name: DS_COR_RACA, dtype: int64

# %%
df.query('NM_UE == "SÃO JOSÉ DOS CAMPOS"')['DS_GRAU_INSTRUCAO'].value_counts().head().plot(kind='barh')

# %%
df.query('NM_UE == "SÃO JOSÉ DOS CAMPOS"')['DS_ESTADO_CIVIL'].value_counts().head().plot(kind='barh')

# %%
df.query('NM_UE == "SÃO JOSÉ DOS CAMPOS"')['DS_OCUPACAO'].value_counts().head().plot(kind='barh')

# %%
df.query('NM_UE == "SÃO JOSÉ DOS CAMPOS"')['DS_GENERO'].value_counts().head()
# Out:
# MASCULINO    418
# FEMININO     203
# Name: DS_GENERO, dtype: int64

# %%
df.query('NM_UE == "SÃO JOSÉ DOS CAMPOS"')['SG_PARTIDO'].value_counts().head()
# Out:
# PT      34
# PSD     34
# PSL     34
# PSDB    34
# PL      33
# Name: SG_PARTIDO, dtype: int64
